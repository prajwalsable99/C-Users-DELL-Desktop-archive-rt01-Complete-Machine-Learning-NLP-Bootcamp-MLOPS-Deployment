# %%
text='''Beans. I was trying to explain to somebody as we were flying in, that’s corn.  That’s beans. And they were very impressed at my agricultural knowledge. Please give it up for Amaury once again for that outstanding introduction. I have a bunch of good friends here today, including somebody who I served with, who is one of the finest senators in the country, and we’re lucky to have him, your Senator, Dick Durbin is here. I also noticed, by the way, former Governor Edgar here, who I haven’t seen in a long time, and somehow he has not aged and I have. And it’s great to see you, Governor. I want to thank President Killeen and everybody at the U of I System for making it possible for me to be here today. And I am deeply honored at the Paul Douglas Award that is being given to me. He is somebody who set the path for so much outstanding public service here in Illinois. Now, I want to start by addressing the elephant in the room. I know people are still wondering why I didn’t speak at the commencement.'''

# %%
import nltk
import re
df = nltk.sent_tokenize(text) 
for i in range(len(df)): 
    df[i] = df[i].lower() 
    df[i] = re.sub(r'\W', ' ', df[i]) 
    df[i] = re.sub(r'\s+', ' ', df[i])

# %%
df
# Out:
# ['beans ',
#  'i was trying to explain to somebody as we were flying in that s corn ',
#  'that s beans ',
#  'and they were very impressed at my agricultural knowledge ',
#  'please give it up for amaury once again for that outstanding introduction ',
#  'i have a bunch of good friends here today including somebody who i served with who is one of the finest senators in the country and we re lucky to have him your senator dick durbin is here ',
#  'i also noticed by the way former governor edgar here who i haven t seen in a long time and somehow he has not aged and i have ',
#  'and it s great to see you governor ',
#  'i want to thank president killeen and everybody at the u of i system for making it possible for me to be here today ',
#  'and i am deeply honored at the paul douglas award that is being given to me ',
#  'he is somebody who set the path for so much outstanding public service here in illinois ',
#  'now i want to start by addressing the elephant in the room ',
#  'i know people are still wondering why i didn t speak at the commencement ']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
len(df)
# Out:
# 13

# %%
tfidf=TfidfVectorizer(max_features=150,ngram_range=(1,2))

# %%
sparse=tfidf.fit_transform(df)

# %%
tfidf.get_feature_names_out()
# Out:
# array(['addressing', 'and', 'at', 'at the', 'beans', 'bunch of', 'by',
#        'by addressing', 'by the', 'commencement', 'corn', 'country',
#        'for', 'governor', 'have', 'he', 'here', 'here today', 'in',
#        'in the', 'is', 'it', 'making', 'me', 'my agricultural',
#        'not aged', 'noticed', 'noticed by', 'now', 'now want', 'of',
#        'of good', 'of system', 'of the', 'once', 'once again', 'one',
#        'one of', 'outstanding', 'outstanding introduction',
#        'outstanding public', 'path', 'path for', 'paul', 'paul douglas',
#        'people', 'people are', 'please', 'please give', 'possible',
#        'possible for', 'president', 'president killeen', 'public',
#        'public service', 're', 're lucky', 'room', 'see', 'see you',
#        'seen', 'seen in', 'senator', 'senator dick', 'senators',
#        'senators in', 'served', 'served with', 'service', 'service here',
#        'set', 'set the', 'so', 'so much', 'somebody', 'somebody as',
#        'somebody who', 'somehow', 'somehow he', 'speak', 'speak at',
#        'start', 'start by', 'still', 'still wondering', 'system',
#        'system for', 'thank', 'thank president', 'that', 'that beans',
#        'that corn', 'that is', 'that outstanding', 'the',
#        'the commencement', 'the country', 'the elephant', 'the finest',
#        'the of', 'the path', 'the paul', 'the room', 'the way', 'they',
#        'they were', 'time', 'time and', 'to', 'to be', 'to explain',
#        'to have', 'to me', 'to see', 'to somebody', 'to start',
#        'to thank', 'today', 'today including', 'trying', 'trying to',
#        'up', 'up for', 'very', 'very impressed', 'want', 'want to', 'was',
#        'was trying', 'way', 'way former', 'we', 'we re', 'we were',
#        'were', 'were flying', 'were very', 'who', 'who haven', 'who is',
#        'who served', 'who set', 'why', 'why didn', 'with', 'with who',
#        'wondering', 'wondering why', 'you', 'you governor'], dtype=object)

# %%
sparse.toarray().shape
# Out:
# (13, 150)

# %%
import pandas as pd
mat=pd.DataFrame(sparse.toarray(),columns=tfidf.get_feature_names_out())

# %%
mat
# Out:
#     addressing       and        at    at the     beans  bunch of        by  \
# 0     0.000000  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.578997  0.000000  0.000000
# 3     0.000000  0.209190  0.250761  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5     0.000000  0.088680  0.000000  0.000000  0.000000  0.154295  0.000000
# 6     0.000000  0.256848  0.000000  0.000000  0.000000  0.000000  0.192691
# 7     0.000000  0.217402  0.000000  0.000000  0.000000  0.000000  0.000000
# 8     0.000000  0.117683  0.141069  0.156579  0.000000  0.000000  0.000000
# 9     0.000000  0.193708  0.232203  0.257732  0.000000  0.000000  0.000000
# 10    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11    0.259768  0.000000  0.000000  0.000000  0.000000  0.000000  0.224014
# 12    0.000000  0.000000  0.188635  0.209374  0.000000  0.000000  0.000000
#
#     by addressing    by the  commencement  ...  who served   who set  \
# 0        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 1        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 2        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 3        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 4        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 5        0.000000  0.000000      0.000000  ...    0.154295  0.000000
# 6        0.000000  0.223445      0.000000  ...    0.000000  0.000000
# 7        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 8        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 9        0.000000  0.000000      0.000000  ...    0.000000  0.000000
# 10       0.000000  0.000000      0.000000  ...    0.000000  0.231136
# 11       0.259768  0.000000      0.000000  ...    0.000000  0.000000
# 12       0.000000  0.000000      0.273796  ...    0.000000  0.000000
#
#          why  why didn      with  with who  wondering  wondering why  \
# 0   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 1   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 2   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 3   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 4   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 5   0.000000  0.000000  0.154295  0.154295   0.000000       0.000000
# 6   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 7   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 8   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 9   0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 10  0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 11  0.000000  0.000000  0.000000  0.000000   0.000000       0.000000
# 12  0.273796  0.273796  0.000000  0.000000   0.273796       0.273796
#
#          you  you governor
# 0   0.000000      0.000000
# 1   0.000000      0.000000
# 2   0.000000      0.000000
# 3   0.000000      0.000000
# 4   0.000000      0.000000
# 5   0.000000      0.000000
# 6   0.000000      0.000000
# 7   0.378259      0.378259
# 8   0.000000      0.000000
# 9   0.000000      0.000000
# 10  0.000000      0.000000
# 11  0.000000      0.000000
# 12  0.000000      0.000000
#
# [13 rows x 150 columns]

# %%
tfidf.vocabulary_
# Out:
# {'beans': 4,
#  'was': 127,
#  'trying': 119,
#  'to': 108,
#  'somebody': 74,
#  'we': 131,
#  'were': 134,
#  'in': 18,
#  'that': 89,
#  'corn': 10,
#  'was trying': 128,
#  'trying to': 120,
#  'to explain': 110,
#  'to somebody': 114,
#  'somebody as': 75,
#  'we were': 133,
#  'were flying': 135,
#  'that corn': 91,
#  'that beans': 90,
#  'and': 1,
#  'they': 104,
#  'very': 123,
#  'at': 2,
#  'they were': 105,
#  'were very': 136,
#  'very impressed': 124,
#  'my agricultural': 24,
#  'please': 47,
#  'it': 21,
#  'up': 121,
#  'for': 12,
#  'once': 34,
#  'outstanding': 38,
#  'please give': 48,
#  'up for': 122,
#  'once again': 35,
#  'that outstanding': 93,
#  'outstanding introduction': 39,
#  'have': 14,
#  'of': 30,
#  'here': 16,
#  'today': 117,
#  'who': 137,
#  'served': 66,
#  'with': 144,
#  'is': 20,
#  'one': 36,
#  'the': 94,
#  'senators': 64,
#  'country': 11,
#  're': 55,
#  'senator': 62,
#  'bunch of': 5,
#  'of good': 31,
#  'here today': 17,
#  'today including': 118,
#  'somebody who': 76,
#  'who served': 140,
#  'served with': 67,
#  'with who': 145,
#  'who is': 139,
#  'one of': 37,
#  'of the': 33,
#  'the finest': 98,
#  'senators in': 65,
#  'in the': 19,
#  'the country': 96,
#  'we re': 132,
#  're lucky': 56,
#  'to have': 111,
#  'senator dick': 63,
#  'noticed': 26,
#  'by': 6,
#  'way': 129,
#  'governor': 13,
#  'seen': 60,
#  'time': 106,
#  'somehow': 77,
#  'he': 15,
#  'noticed by': 27,
#  'by the': 8,
#  'the way': 103,
#  'way former': 130,
#  'who haven': 138,
#  'seen in': 61,
#  'time and': 107,
#  'somehow he': 78,
#  'not aged': 25,
#  'see': 58,
#  'you': 148,
#  'to see': 113,
#  'see you': 59,
#  'you governor': 149,
#  'want': 125,
#  'thank': 87,
#  'president': 51,
#  'system': 85,
#  'making': 22,
#  'possible': 49,
#  'me': 23,
#  'want to': 126,
#  'to thank': 116,
#  'thank president': 88,
#  'president killeen': 52,
#  'at the': 3,
#  'the of': 99,
#  'of system': 32,
#  'system for': 86,
#  'possible for': 50,
#  'to be': 109,
#  'paul': 43,
#  'the paul': 101,
#  'paul douglas': 44,
#  'that is': 92,
#  'to me': 112,
#  'set': 70,
#  'path': 41,
#  'so': 72,
#  'public': 53,
#  'service': 68,
#  'who set': 141,
#  'set the': 71,
#  'the path': 100,
#  'path for': 42,
#  'so much': 73,
#  'outstanding public': 40,
#  'public service': 54,
#  'service here': 69,
#  'now': 28,
#  'start': 81,
#  'addressing': 0,
#  'room': 57,
#  'now want': 29,
#  'to start': 115,
#  'start by': 82,
#  'by addressing': 7,
#  'the elephant': 97,
#  'the room': 102,
#  'people': 45,
#  'still': 83,
#  'wondering': 146,
#  'why': 142,
#  'speak': 79,
#  'commencement': 9,
#  'people are': 46,
#  'still wondering': 84,
#  'wondering why': 147,
#  'why didn': 143,
#  'speak at': 80,
#  'the commencement': 95}
