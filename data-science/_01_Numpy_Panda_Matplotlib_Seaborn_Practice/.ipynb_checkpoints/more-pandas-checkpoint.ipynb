# %%
import pandas as pd

# %%
df= pd.read_csv('data.csv',encoding="ISO-8859-1", dtype={'CustomerID': str})
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom
# 3  12/1/2010 8:26       3.39      17850  United Kingdom
# 4  12/1/2010 8:26       3.39      17850  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 33.1+ MB

# %%
df.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.rename(columns={'InvoiceNo':'invNo'},inplace=True)

# %%
df.head()
# Out:
#     invNo StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom
# 3  12/1/2010 8:26       3.39      17850  United Kingdom
# 4  12/1/2010 8:26       3.39      17850  United Kingdom

# %%
df['CustomerID'].unique().shape
# Out:
# (4373,)

# %%
df.groupby('CustomerID')['Quantity'].agg(['mean','max','count'])
# Out:
#                  mean    max   count
# CustomerID
# 0            1.995573   5568  135080
# 12346        0.000000  74215       2
# 12347       13.505495    240     182
# 12348       75.516129    144      31
# 12349        8.643836     36      73
# ...               ...    ...     ...
# 18280        4.500000      8      10
# 18281        7.714286     12       7
# 18282        7.538462     48      13
# 18283        1.847884     13     756
# 18287       22.657143     60      70
#
# [4373 rows x 3 columns]

# %%
df1= pd.DataFrame( {"c":[1,2],"b":[3,4]})
df2= pd.DataFrame( {"c":[1,2],"d":[7,8]})

# %%
pd.merge(df1,df2,on='c',how='right')
# Out:
#    c  b  d
# 0  1  3  7
# 1  2  4  8

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
table_MN
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1                                            FlagSeal
#  2   Nicknames: Mni Sóta Makoce (Land where the wat...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...

# %%
len(table_MN)
# Out:
# 29

# %%
df=table_MN[5]

# %%
df
# Out:
#                         Race Percentage
# 0                      White      77.5%
# 1  Black or African American       7.0%
# 2            American Indian       1.2%
# 3                      Asian       5.3%
# 4           Pacific Islander       0.1%
# 5                 Other race       3.2%
# 6          Two or more races       6.1%
