# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
x= 6* np.random.rand(100,1) -3
y= 0.5* x**2 + 1.5*x +2 + np.random.randn(100,1)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score(y_test,model.predict(x_test))
# Out:
# 0.7498836161160646

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,model.predict(x_test),color='r')

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)

# %%
x_train_py=poly.fit_transform(x_train)
x_test_py=poly.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train_py,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_test,model.predict(x_test_py))
# Out:
# 0.9128057209301972

# %%
x_test.shape
# Out:
# (30, 1)

# %%
# plt.scatter(y_test)
plt.scatter(x=x_test,y=model.predict(x_test_py),color='r',label='predicted')
plt.scatter(x=x_test,y=y_test,color='g',label='actual')


plt.show()

# %%
# Out:
# C:\Users\PS001028870\AppData\Local\Temp\ipykernel_6992\2036283495.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
