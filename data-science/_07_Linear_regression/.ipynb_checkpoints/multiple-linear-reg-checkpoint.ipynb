# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('multiple_linear_regression_dataset.csv')
df.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   32           5   40130
# 3   43          10   47830
# 4   51           7   41630

# %%
x=df.drop(['income'],axis=1)
y=df['income']

# %%
sns.pairplot(data=df)

# %%
df.corr()
# Out:
#                  age  experience    income
# age         1.000000    0.807712  0.732413
# experience  0.807712    1.000000  0.975773
# income      0.732413    0.975773  1.000000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
sns.regplot(x='age',y='income',data=df)
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
sns.regplot(x='experience',y='income',data=df)
# Out:
# <Axes: xlabel='experience', ylabel='income'>

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([-957.86822222, 5990.32714769]), 42802.72727272727)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8956380791028329

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1926.781205707688

# %%
from sklearn.model_selection import cross_val_score

# %%
cv=cross_val_score(model,x_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
cv
# Out:
# array([-1713508.58761382, -1746370.63589995, -6477177.39369869])
